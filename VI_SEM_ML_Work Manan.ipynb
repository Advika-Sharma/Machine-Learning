# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Concatenation Operation
l1 = [1,2,3]
l2 = [4,5,6]
print(l1+l2)
'''
Creation of list using square brackets
Creation of tuple using simple parenthesis
Creation of set and dictionary using curly brackets
'''
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l1*l2 #This is not working because we are trying to perform mathematical operation on list without the use of numpy which is not possible over list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-bd77ec8884ac> in <cell line: 1>()
# ----> 1 l1*l2
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
l1*2 #Repeated concatenation of the same list and this is happening because we are not using numpy library
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a = np.array([[1,2,3],[4,5,6]], dtype='int64')
a #Use of numpy to create an array with the use of list, 2D Array is created and dtype to mention the size of int we require
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a.ndim #To check the dimension of the array
# Out:
# 2

# %%
a.shape #To check the structure of the array 2 rows and 3 columns
# Out:
# (2, 3)

# %%
a.size #To check the size of the array or the number of elements it consist of
# Out:
# 6

# %%
a.itemsize #To check the size a particular element take the memory bytes
# Out:
# 8

# %%
#To create a 3D array with numpy
array3D = np.array([[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]]])

# %%
array3D.ndim #To check the dimension of the array which is three as the array is 3D
# Out:
# 3

# %%
array3D #The order 2 X 3 X 4 represents that there should be 2 rows and there should be 3 columns and the number of 2D matrices that should be there are 4 which is represented by the z coordinate
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]])

# %%
a.max() #To derieve out the maximum value in the array, function so brackets after max
# Out:
# 6

# %%
a.min() #To derieve out the minimum value in the array
# Out:
# 1

# %%
a.sum() #Function to do the sum of elements of the array
# Out:
# 21

# %%
np.sqrt(a) #Function to find out the square root of all the elements of the array
# Out:
# array([[1.        , 1.41421356, 1.73205081],
#        [2.        , 2.23606798, 2.44948974]])

# %%
np.std(a) #Function to find the standard deviation of the elements of the array
# Out:
# 1.707825127659933

# %%
array3D.sum(axis = 0) #The axis is used to change the axis on the basis of which the sum of elements is taking place
# Out:
# array([[ 4,  8, 12],
#        [16, 20, 24]])

# %%
a.sum(axis = 0) #Sum of elements is happening column wise
# Out:
# array([5, 7, 9])

# %%
a.sum(axis = 1) #Sum of elements is happening row wise
# Out:
# array([ 6, 15])

# %%
a[0: , 2] # ':' is used for the slicing purposes where we are starting from zeroeth row till the end as nothing mentioned after colon and we are doing this in the 2nd column
# Out:
# array([3, 6])

# %%
statement = 'This is the first default of new world!!'

# %%
statement[0:8] #We have use slicing to slice the string from 0th index to 8th index where 8th index is not included
# Out:
# 'This is '

# %%
statement[-9 : -1] #To slice from the end where the last character has index -1 and elements before them has index in increasing from -2 then -3 and so on
# Out:
# 'w world!'

# %%
statement[0:-1] #Both forward and reverse approaches can be mixed where the first index is greater that is positive and the second index is negative for working, in this we have started slicing from 0th index and will go till last character but will not include last character
# Out:
# 'This is the first default of new world!'

# %%
statement[::-1] #This is to reverse the string
'''
[start:stop:step]
collection denotes the data collection (list, string, array, and so on).
start denotes where the slicing operation should start from.
stop denotes where the operation should stop.
step denotes the sequence of iterating through the elements.
'''
# Out:
# '!!dlrow wen fo tluafed tsrif eht si sihT'

# %%
import pandas as pd #import a file using import and there is a use of aliases as to give it a nickname and it can be anything but pd, np, etc. are the standard nicknames

# %%
df = pd.read_csv('/content/customerDataset.csv') #pd.read_excel funtion to read a excel file and read_csv function to read a csv file

# %%
df
# Out:
#         Index      Customer Id First Name   Last Name  \
# 0           1  ffeCAb7AbcB0f07      Jared      Jarvis
# 1           2  b687FfC4F1600eC      Marie      Malone
# 2           3  9FF9ACbc69dcF9c     Elijah     Barrera
# 3           4  b49edDB1295FF6E     Sheryl  Montgomery
# 4           5  3dcCbFEB17CCf2E     Jeremy     Houston
# ...       ...              ...        ...         ...
# 99995   99996  67F24BEBAa16d1c       Dana     Winters
# 99996   99997  17b1dbDaB2ad0fB   Gabriela     Pacheco
# 99997   99998  c586CFBA6fb9dcC    Mikayla     Hubbard
# 99998   99999  bb6cb6AC9d0CAf7     Javier        Berg
# 99999  100000  FaE5E3c1Ea0dEc2     Kaylee     Hubbard
#
#                          Company             City  \
# 0               Sanchez-Fletcher    Hatfieldshire
# 1                      Mckay PLC   Robertsonburgh
# 2                 Marks and Sons          Kimbury
# 3      Kirby, Vaughn and Sanders      Briannaview
# 4                 Lester-Manning    South Brianna
# ...

# %%
df.head() #To print the first few rows of the dataset as a preview we can mention the number of rows we want to see, head() prints first five rows by default if no parameter, we can write df.head(10) to print first 10 rows
# Out:
#    Index      Customer Id First Name   Last Name                    Company  \
# 0      1  ffeCAb7AbcB0f07      Jared      Jarvis           Sanchez-Fletcher
# 1      2  b687FfC4F1600eC      Marie      Malone                  Mckay PLC
# 2      3  9FF9ACbc69dcF9c     Elijah     Barrera             Marks and Sons
# 3      4  b49edDB1295FF6E     Sheryl  Montgomery  Kirby, Vaughn and Sanders
# 4      5  3dcCbFEB17CCf2E     Jeremy     Houston             Lester-Manning
#
#              City                                       Country  \
# 0   Hatfieldshire                                       Eritrea
# 1  Robertsonburgh                                      Botswana
# 2         Kimbury                                      Barbados
# 3     Briannaview  Antarctica (the territory South of 60 deg S)
# 4   South Brianna                                    Micronesia
#
#                 Phone 1               Phone 2  \
# 0    274.188.8773x41185  001-215-760-4642x969
# ...

# %%
df.sample() #This function will give a random tuple out of the dataset
# Out:
#        Index      Customer Id First Name Last Name          Company  \
# 78256  78257  724Dd0a1BA6dEfc    Marissa   Barnett  Alvarado-Chaney
#
#                     City            Country             Phone 1  \
# 78256  East Lawrenceland  Equatorial Guinea  299-619-6231x52636
#
#                  Phone 2                        Email Subscription Date  \
# 78256  246-980-1058x4784  grace49@valencia-wright.biz        2021-11-10
#
#                       Website
# 78256  http://www.acosta.com/

# %%
df.tail() #This function is to print rows from the end
# Out:
#         Index      Customer Id First Name Last Name                Company  \
# 99995   99996  67F24BEBAa16d1c       Dana   Winters  Pham, Conner and Wade
# 99996   99997  17b1dbDaB2ad0fB   Gabriela   Pacheco         Fletcher-Hodge
# 99997   99998  c586CFBA6fb9dcC    Mikayla   Hubbard             Austin Ltd
# 99998   99999  bb6cb6AC9d0CAf7     Javier      Berg              Welch Inc
# 99999  100000  FaE5E3c1Ea0dEc2     Kaylee   Hubbard            Booker-Luna
#
#                   City       Country                Phone 1  \
# 99995         Kirkfurt  Sierra Leone           820-930-7616
# 99996    Virginiahaven       Comoros        +1-480-464-8646
# 99997       Sheriville       Mayotte  +1-567-149-3941x67118
# 99998  Stephenschester       Belarus          (381)105-4698
# 99999       New Karina       Estonia     (184)132-6303x4566
#
#                     Phone 2                               Email  \
# 99995  +1-061-779-5511x3267                 ppittman@watson.com
# ...

# %%
df[39:43] #Use of slicing to print some specific tuples , use of loc and iloc can also be done to do segment
# Out:
#     Index      Customer Id First Name Last Name  \
# 39     40  06bDd08a9FdC9bF     Julian      Horn
# 40     41  E3BBfaF61f6E5b1     Alfred    Haynes
# 41     42  f53cabB1CA1aEEa     Melody    Forbes
# 42     43  2ad0E94a2b6e18E   Courtney  Guerrero
#
#                           Company                City      Country  \
# 39       Herman, Calhoun and Holt         Phyllisland        Samoa
# 40         West, Huynh and Galvan  Lake Lorraineshire      Bahamas
# 41                    Roach Group            Port Kim      Senegal
# 42  Estrada, Chandler and Edwards          Gordonstad  Isle of Man
#
#                 Phone 1              Phone 2                        Email  \
# 39  +1-193-394-4602x348         914-974-3568       bethashley@harding.com
# 40         913.878.6789  +1-033-557-1501x654  obriengloria@brady-cole.com
# 41         582.331.5901    439-950-7863x6747      rherrera@williamson.com
# 42   209.479.1833x17794      +1-636-652-7799    xzamora@foley-ellison.com
#
# ...

# %%
df.columns #To print all the column name of the dataframe that is taken
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
df['Phone 2'] #To print a specific column of dataframe
# Out:
# 0        001-215-760-4642x969
# 1         (189)129-8356x63741
# 2           459-916-7241x0909
# 3               (392)819-9063
# 4            252-488-3850x692
#                  ...
# 99995    +1-061-779-5511x3267
# 99996     (015)822-1443x33211
# 99997            361-900-3348
# 99998        360-905-2308x301
# 99999            157.189.4485
# Name: Phone 2, Length: 100000, dtype: object

# %%
df[['First Name','Last Name']] #To print two columns together you can create a list of the columns that you want to print
# Out:
#       First Name   Last Name
# 0          Jared      Jarvis
# 1          Marie      Malone
# 2         Elijah     Barrera
# 3         Sheryl  Montgomery
# 4         Jeremy     Houston
# ...          ...         ...
# 99995       Dana     Winters
# 99996   Gabriela     Pacheco
# 99997    Mikayla     Hubbard
# 99998     Javier        Berg
# 99999     Kaylee     Hubbard
#
# [100000 rows x 2 columns]

# %%
df['City'].nunique() #To print the unique values that are there within the column
# Out:
# 49154

# %%
df.nunique() #To print the number of unique values in all the columns
# Out:
# Index                100000
# Customer Id          100000
# First Name              690
# Last Name              1000
# Company               71994
# City                  49154
# Country                 243
# Phone 1              100000
# Phone 2              100000
# Email                 99995
# Subscription Date       880
# Website               50471
# dtype: int64

# %%
df.describe()
# Out:
#                Index
# count  100000.000000
# mean    50000.500000
# std     28867.657797
# min         1.000000
# 25%     25000.750000
# 50%     50000.500000
# 75%     75000.250000
# max    100000.000000

# %%
#Find-S Algorithm Implementation on a weather dataset
df2 = pd.read_csv('/content/weatherDataset.csv')

# %%
df2
# Out:
#       Time Weather Temperature Company Humidity    Wind Goes
# 0  Morning   Sunny        Warm     Yes     Mild  Strong  Yes
# 1  Evening   Rainy        Cold      No     Mild  Normal   No
# 2  Morning   Sunny    Moderate     Yes   Normal  Normal  Yes
# 3  Evening   Sunny        Cold     Yes     High  Strong  Yes

# %%
df2 = pd.DataFrame(df2)

# %%
df1 = { 'Time': ['Morning', 'Evening', 'Morning', 'Evening'],
       'Weather': ['Sunny', 'Rainy', 'Sunny', 'Sunny'],
        'Temperature': ['Warm', 'Cold', 'Moderate', 'Cold'],
        'Company': ['Yes', 'No', 'Yes', 'Yes'],
        'Humidity': ['Mild', 'Mild', 'Normal', 'High'],
        'Wind': ['Strong', 'Normal', 'Normal', 'Strong'],
        'Goes': ['Yes', 'No', 'Yes', 'Yes'] }

# %%
df1
# Out:
#       Time Weather Temperature Company Humidity    Wind Goes
# 0  Morning   Sunny        Warm     Yes     Mild  Strong  Yes
# 1  Evening   Rainy        Cold      No     Mild  Normal   No
# 2  Morning   Sunny    Moderate     Yes   Normal  Normal  Yes
# 3  Evening   Sunny        Cold     Yes     High  Strong  Yes

# %%
finalList = ['0', '0', '0', '0', '0', '0']
for index, row in df1.iterrows():
  if row['Goes'] == 'Yes':
    for i, key in enumerate(df1.columns[:-1]):
      if finalList[i] == '0':
        finalList[i] = row[key]
      elif finalList[i] != row[key]:
        finalList[i] = '?'

# %%
finalList = ['0', '0', '0', '0', '0', '0']
for index, row in df1.iterrows():
  if row['Goes'] == 'Yes':
    for i, key in enumerate(df1.columns[:-1]):
      if finalList[i] == '0':
        finalList[i] = row[key]
      elif finalList[i] != row[key]:
        finalList[i] = '?'

print('The Final List of general conclusion is:', finalList)
# Out:
# The Final List of general conclusion is: ['?', 'Sunny', '?', 'Yes', '?', '?']

# %%
finalList1 = ['0', '0', '0', '0', '0', '0']
for index, row in df2.iterrows():
  if row['Goes'] == 'Yes':
    for i, key in enumerate(df2.columns[:-1]):
      if finalList1[i] == '0':
        finalList1[i] = row[key]
      elif finalList1[i] != row[key]:
        finalList1[i] = '?'

print('The Final List of general conclusion is:', finalList1)
# Out:
# The Final List of general conclusion is: ['?', 'Sunny', '?', 'Yes', '?', '?']

# %%
finalList3 = ['0','0','0','0','0','0']

for index,row in df1.iterrows():
  if df1.iloc[index,-1] == 'Yes':
    for i,key in enumerate(df1.columns[:-1]):
      if finalList3[i] == '0':
        finalList3[i] = row[key]
      elif finalList3[i] != row[key]:
        finalList3[i] = '?'

finalList3
# Out:
# ['?', 'Sunny', '?', 'Yes', '?', '?']

# %%
#Candidate Elimination
#Code of candidate elimination to be done and Find-S to be done in the lab manual

# %%
data = pd.read_csv('2.csv')
concepts = np.array(data.iloc[:,0:-1])
target = np.array(data.iloc[:,-1])
def learn(concepts, target):
    specific_h = concepts[0].copy()
    print("initialization of specific_h \n",specific_h)
    general_h = [["?" for i in range(len(specific_h))] for i in range(len(specific_h))]
    print("initialization of general_h \n", general_h)

    for i, h in enumerate(concepts):
        if target[i] == "yes":
            print("If instance is Positive ")
            for x in range(len(specific_h)):
                if h[x]!= specific_h[x]:
                    specific_h[x] ='?'
                    general_h[x][x] ='?'

        if target[i] == "no":
            print("If instance is Negative ")
            for x in range(len(specific_h)):
                if h[x]!= specific_h[x]:
                    general_h[x][x] = specific_h[x]
                else:
                    general_h[x][x] = '?'

        print(" step {}".format(i+1))
        print(specific_h)
        print(general_h)
        print("\n")
        print("\n")

    indices = [i for i, val in enumerate(general_h) if val == ['?', '?', '?', '?', '?', '?']]
    for i in indices:
        general_h.remove(['?', '?', '?', '?', '?', '?'])
    return specific_h, general_h

s_final, g_final = learn(concepts, target)

print("Final Specific_h:", s_final, sep="\n")
print("Final General_h:", g_final, sep="\n")

# %%
#Linear Regression
#y=mx+c is the equation of the Linear Regression where m is the slope and c is the intercept where m is the importance of the feature with respect to the value we can say it as y = a + a1x + a2x and so on where a,a1,a2 are importance of the features

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.shape
# Out:
# (200, 2)

# %%
df.size
# Out:
# 400

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.iloc[:,:-1]
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
Y = df.iloc[:,-1]
Y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train, x_test, y_train, y_test = tts(X,Y,test_size=0.25, random_state=2)

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
model = LR()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([3.90615968, 3.09604194, 2.37656675, 2.56918215, 1.63443092,
#        1.75906442, 2.05931784, 2.93175233, 3.77586102, 2.93741749,
#        4.1101054 , 3.52092887, 2.97140844, 2.39356223, 3.19234964,
#        3.47560759, 1.92901919, 3.24900123, 2.9770736 , 3.42462116,
#        2.55218668, 3.16968901, 2.85810526, 3.12436774, 3.69654879,
#        2.86943558, 3.50393339, 3.3509741 , 3.93448547, 1.94601466,
#        3.66255784, 3.21501028, 3.75320038, 2.7844582 , 2.77879304,
#        3.27732703, 3.53792434, 2.60883827, 2.65415954, 2.71081113,
#        3.09037678, 4.10444024, 2.11596943, 1.93468435, 3.4472818 ,
#        2.87510074, 2.94874781, 2.82977947, 3.52659402, 3.51526371])

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61, 3.13, 3.91, 2.25, 2.3 ,
#        4.06, 3.18, 2.7 , 2.49, 3.15, 2.99])

# %%
from sklearn.metrics import mean_absolute_error as mae, r2_score as r2, mean_squared_error as mse

# %%
mae(y_pred, y_test)
# Out:
# 0.2925721381522003

# %%
r2(y_pred,y_test)
# Out:
# 0.676411664294233

# %%
mse(y_pred,y_test)
# Out:
# 0.12137452429115214

# %%
mae(y_test,y_pred) #this is the right way to write for accuracy calculation, more close to zero more good
# Out:
# 0.2925721381522003

# %%
r2(y_test,y_pred) #standard value of r2score is 0.7-0.8 if 0 there is no dependency and if 1 then there is a whole lot of dependency between them
# Out:
# 0.7626756914759928

# %%
mse(y_test,y_pred)  #more close to zero more good
# Out:
# 0.12137452429115214

# %%
print(model.coef_)
# Out:
# [0.5665159]

# %%
print(model.intercept_)
# Out:
# -0.9545467420146729

# %%
df1 = pd.read_csv('/content/FuelConsumption.csv')

# %%
df1.shape
# Out:
# (1067, 13)

# %%
df1
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
X1 = df1.iloc[:,4:6]

# %%
Y1 = df1.iloc[:,-1]

# %%
X_train, X_test, Y_train, Y_test = tts(X1, Y1, test_size=0.25, random_state=42)

# %%
model1 = LR()

# %%
model1.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model1.predict(X_test)

# %%
r2(Y_test, Y_pred)
# Out:
# 0.778932425895301

# %%
model1.coef_
# Out:
# array([29.12629592,  8.18294354])

# %%
mae(Y_test, Y_pred)
# Out:
# 23.514317003992982

# %%
mse(Y_test, Y_pred)
# Out:
# 916.9824985061896

# %%
model1.intercept_
# Out:
# 111.95973664426802

# %%
#Visualization in machine learning using matplotlib.pyplot and seaborn

# %% [markdown]
# **Scatter Plot of CGPA and Package in placement.csv dataframe**

# %%
x_coordinate = df['cgpa']
y_coordinate = df['package']

# %%
plt.scatter(x_coordinate,y_coordinate)
plt.plot(x_train, model.predict(x_train), color = "red")
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.title('Scatter Line Plot for Package V/S CGPA')
# Out:
# Text(0.5, 1.0, 'Scatter Line Plot for Package V/S CGPA')

# %%
#To implement linear regression on placement.csv file and also draw the above visualization in file

# %%
#To implement KNN Algorithm
#Data Preprocessing step is also included
#To implement KNN till accuracy score then you have to write output of size, shape and head, then you have to apply graphs using matplotlib in which one graph will be of ytest and ypred comparison and the other graph will of k cross validation implementation which will be a line graph

# %%
df = pd.read_csv('/content/breast-cancer.csv')

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.size
# Out:
# 18208

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.isnull().sum() #This is used to check if there are any null values in the dataset and if there are any then how many of them are there and there sum w.r.t each column
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df.drop(["id"],axis = 1,inplace=True)

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
X = df.iloc[:,1:]

# %%
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
Y = df.iloc[:,0]

# %%
Y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train, x_test, y_train, y_test = tts(X, Y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler as SS

# %%
scalar = SS() #Making an object of the StandardScaler file that we have imported as SS

# %%
x_train = scalar.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.34913849, -1.43851335, -0.41172595, ..., -0.91671059,
#         -0.92508585, -0.80841115],
#        [-0.20468665,  0.31264011, -0.13367256, ...,  1.43655962,
#          1.14955889,  1.56911143],
#        [-0.32931176, -0.21507235, -0.31739376, ..., -0.7237126 ,
#          0.53496977, -0.61934827],
#        ...,
#        [ 0.04739597, -0.56293662, -0.06529202, ..., -1.23262438,
#         -0.68282718, -1.261137  ],
#        [-0.04040808,  0.09966199, -0.03151368, ...,  1.08847951,
#          0.48944465,  1.26159953],
#        [-0.5502381 ,  0.31264011, -0.6040977 , ..., -0.59582424,
#         -0.29911546, -0.82948141]])

# %%
x_test = scalar.transform(x_test)

# %%
x_test
# Out:
# array([[-0.46809882, -0.14171322, -0.44468042, ..., -0.17331092,
#          0.22117163,  0.23655985],
#        [ 1.36445686,  0.49958757,  1.30643802, ...,  1.0294302 ,
#         -0.53161875, -0.99405722],
#        [ 0.37878549,  0.06653205,  0.40430925, ...,  0.6020997 ,
#         -0.06661217, -0.17972015],
#        ...,
#        [-0.87313045, -0.5605702 , -0.86361419, ..., -0.59582424,
#          0.19515727, -0.25830652],
#        [ 1.6108747 ,  0.69836715,  1.57007383, ...,  1.96023373,
#         -0.17879907, -0.40978461],
#        [-1.09405679, -1.65149148, -1.07658249, ..., -0.71003802,
#          0.09597755, -0.34885169]])

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

# %%
knn = KNN(n_neighbors=9)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_pred = knn.predict(x_test)

# %%
y_pred
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B'],
#       dtype=object)

# %%
y_test
# Out:
# 204    B
# 70     M
# 131    M
# 431    B
# 540    B
#       ..
# 89     B
# 199    M
# 411    B
# 18     M
# 390    B
# Name: diagnosis, Length: 143, dtype: object

# %%
from sklearn.metrics import accuracy_score #This accuracy score can be applied on any model except linear regression

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.972027972027972

# %%
from sklearn.metrics import confusion_matrix as cm, ConfusionMatrixDisplay as cmd

# %%
CM = cm(y_test, y_pred, labels = ['M','B'])

# %%
disp = cmd(confusion_matrix=CM, display_labels=['M','B'])
disp.plot(cmap = 'Blues')
plt.show()

# %%
scores = []

for i in range(1,16):
  knn = KNN(n_neighbors=i)
  knn.fit(x_train, y_train)
  y_pred = knn.predict(x_test)
  scores.append(accuracy_score(y_test, y_pred))

# %%
plt.plot(range(1,16),scores)

# %%
#Manual Implementation of Linear Regression calculation of coefficient and intercept without using the formula

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.shape
# Out:
# (200, 2)

# %%
X = df.iloc[:,0]

# %%
X
# Out:
# 0      6.89
# 1      5.12
# 2      7.82
# 3      7.42
# 4      6.94
#        ...
# 195    6.93
# 196    5.89
# 197    7.21
# 198    7.63
# 199    6.22
# Name: cgpa, Length: 200, dtype: float64

# %%
Y = df.iloc[:,1]
Y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
noOfObservations = 200

# %%
prodXY = 0
sumX = 0
sumY = 0
sumSquareX = 0
for cg, pack in zip(X,Y):
  sumX = sumX + cg
  sumY = sumY + pack
  sumSquareX = sumSquareX + cg*cg
  prodXY = prodXY + cg*pack

# %%
coefficientOfLine = round(float(((noOfObservations * prodXY) - (sumX*sumY))/((noOfObservations*sumSquareX) - (sumX**2))),2)

# %%
coefficientOfLine
# Out:
# 0.57

# %%
interceptOfLine = round(float((sumY - coefficientOfLine*sumX)/(noOfObservations)),2)

# %%
interceptOfLine
# Out:
# -0.99

# %%
df = pd.read_csv('/content/imdbDataset.csv')

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df['Meta_score'].fillna(df['Meta_score'].mean(), inplace = True)
# Out:
# <ipython-input-8-78e4572f3b48>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Meta_score'].fillna(df['Meta_score'].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score         0
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     1000 non-null   float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df['Certificate'].value_counts()
# Out:
# Certificate
# U           234
# A           197
# UA          175
# R           146
# PG-13        43
# PG           37
# Passed       34
# G            12
# Approved     11
# TV-PG         3
# GP            2
# TV-14         1
# 16            1
# TV-MA         1
# Unrated       1
# U/A           1
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#LabelEncoder OnehotEncoder OrdinalEncoder they are present in sklearn.preprocessing
#oneHotEncoder can be replaced byh get_dummies()
'''
GaussianNB to be explored and applied
Naive Bayes Classification either purchase dataset or employee dataset
'''

# %%
#Implementation of Naive-Bayes Algorithm using GaussianNB
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder as LE, StandardScaler as SS
from sklearn.model_selection import train_test_split as tts
from sklearn.naive_bayes import GaussianNB as GNB
from sklearn import metrics
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
df.shape
# Out:
# (400, 5)

# %%
df.size
# Out:
# 2000

# %%
df.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.drop('User ID', inplace = True, axis = 1)

# %%
le = LE()
df['Gender'] = le.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0       1   19            19000          0
# 1       1   35            20000          0
# 2       0   26            43000          0
# 3       0   27            57000          0
# 4       1   19            76000          0

# %%
#Correlation Matrix
df.corr()
# Out:
#                    Gender       Age  EstimatedSalary  Purchased
# Gender           1.000000 -0.073741        -0.060435  -0.042469
# Age             -0.073741  1.000000         0.155238   0.622454
# EstimatedSalary -0.060435  0.155238         1.000000   0.362083
# Purchased       -0.042469  0.622454         0.362083   1.000000

# %%
df.drop(columns = 'Gender', inplace = True)

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:,-1].values

# %%
x_train, x_test, y_train, y_test = tts(x, y, test_size = 0.2, random_state = 42)

# %%
NBClassifier = GNB()

# %%
NBClassifier.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = NBClassifier.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.925

# %%
print(f'Classification Report:-\n {classification_report(y_test, y_pred)}')
# Out:
# Classification Report:-
#                precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94        52
#            1       0.92      0.86      0.89        28
#
#     accuracy                           0.93        80
#    macro avg       0.92      0.91      0.92        80
# weighted avg       0.92      0.93      0.92        80

# %%
from sklearn.ensemble import BaggingClassifier

# %%
gnb = GNB()

# %%
bagging_clf = BaggingClassifier(estimator=gnb , n_estimators=10, random_state = 2)

# %%
bagging_clf.fit(x_train, y_train)
# Out:
# BaggingClassifier(estimator=GaussianNB(), random_state=2)

# %%
y_pred = bagging_clf.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.85

# %%
scaler = SS()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
gnb.fit(x_train_scaled, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(x_test_scaled)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.85

# %% [markdown]
# ## **Decision Tree Classifier**

# %%
df = pd.read_csv('/content/drug200.csv')

# %%
df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
df['Drug'].value_counts()
# Out:
# Drug
# drugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder as LE

# %%
le = LE()

# %%
df['Sex'] = le.fit_transform(df['Sex'])

# %%
df
# Out:
#      Age  Sex      BP Cholesterol  Na_to_K   Drug
# 0     23    0    HIGH        HIGH   25.355  drugY
# 1     47    1     LOW        HIGH   13.093  drugC
# 2     47    1     LOW        HIGH   10.114  drugC
# 3     28    0  NORMAL        HIGH    7.798  drugX
# 4     61    0     LOW        HIGH   18.043  drugY
# ..   ...  ...     ...         ...      ...    ...
# 195   56    0     LOW        HIGH   11.567  drugC
# 196   16    1     LOW        HIGH   12.006  drugC
# 197   52    1  NORMAL        HIGH    9.894  drugX
# 198   23    1  NORMAL      NORMAL   14.020  drugX
# 199   40    0     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
le1 = LE()

# %%
df['BP'] = le1.fit_transform(df['BP'])

# %%
le2 = LE()

# %%
df['Cholesterol'] = le2.fit_transform(df['Cholesterol'])

# %%
df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0   0            0   25.355  drugY
# 1     47    1   1            0   13.093  drugC
# 2     47    1   1            0   10.114  drugC
# 3     28    0   2            0    7.798  drugX
# 4     61    0   1            0   18.043  drugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   1            0   11.567  drugC
# 196   16    1   1            0   12.006  drugC
# 197   52    1   2            0    9.894  drugX
# 198   23    1   2            1   14.020  drugX
# 199   40    0   1            1   11.349  drugX
#
# [200 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x = df.iloc[:,:-1]

# %%
y = df.iloc[:, -1]

# %%
x_train, x_test, y_train, y_test = tts(x, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier as DTC

# %%
dtc = DTC(criterion='gini')

# %%
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix as cm, ConfusionMatrixDisplay as cmd

# %%
CM = cm(y_test, y_pred, labels = ['drugY','drugX','drugA','drugC','drugB'])

# %%
disp = cmd(confusion_matrix=CM, display_labels=['drugY','drugX','drugA','drugC','drugB'])
disp.plot(cmap = 'Blues')
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
print(f'Classification Report:-\n {classification_report(y_test, y_pred)}')
# Out:
# Classification Report:-
#                precision    recall  f1-score   support
#
#        drugA       1.00      1.00      1.00         6
#        drugB       1.00      1.00      1.00         3
#        drugC       1.00      1.00      1.00         6
#        drugX       1.00      1.00      1.00        15
#        drugY       1.00      1.00      1.00        20
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50

# %%
from sklearn import tree

# %%
tree.plot_tree(dtc)
# Out:
# [Text(0.625, 0.9, 'x[4] <= 14.829\ngini = 0.684\nsamples = 150\nvalue = [17, 13, 10, 39, 71]'),
#  Text(0.5, 0.7, 'x[2] <= 0.5\ngini = 0.667\nsamples = 79\nvalue = [17, 13, 10, 39, 0]'),
#  Text(0.5625, 0.8, 'True  '),
#  Text(0.25, 0.5, 'x[0] <= 50.5\ngini = 0.491\nsamples = 30\nvalue = [17, 13, 0, 0, 0]'),
#  Text(0.125, 0.3, 'gini = 0.0\nsamples = 17\nvalue = [17, 0, 0, 0, 0]'),
#  Text(0.375, 0.3, 'gini = 0.0\nsamples = 13\nvalue = [0, 13, 0, 0, 0]'),
#  Text(0.75, 0.5, 'x[2] <= 1.5\ngini = 0.325\nsamples = 49\nvalue = [0, 0, 10, 39, 0]'),
#  Text(0.625, 0.3, 'x[3] <= 0.5\ngini = 0.499\nsamples = 21\nvalue = [0, 0, 10, 11, 0]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0]'),
#  Text(0.75, 0.1, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0]'),
#  Text(0.875, 0.3, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 0, 28, 0]'),
#  Text(0.75, 0.7, 'gini = 0.0\nsamples = 71\nvalue = [0, 0, 0, 0, 71]'),
#  Text(0.6875, 0.8, '  False')]

# %% [markdown]
# ## **Logistic Regression**

# %%
df = pd.read_csv('/content/customer_churn_dataset-testing-master.csv')

# %%
df
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
df.drop(columns= 'CustomerID', inplace=True)

# %%
le = LE()

# %%
df['Gender'] = le.fit_transform(df['Gender'])

# %%
le1 = LE()

# %%
df['Subscription Type'] = le1.fit_transform(df['Subscription Type'])

# %%
le2 = LE()

# %%
df['Contract Length'] = le2.fit_transform(df['Contract Length'])

# %%
df.head()
# Out:
#    Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0   22       0      25               14              4             27
# 1   41       0      28               28              7             13
# 2   47       1      27               10              2             29
# 3   35       1       9               12              5             17
# 4   53       0      58               24              9              2
#
#    Subscription Type  Contract Length  Total Spend  Last Interaction  Churn
# 0                  0                1          598                 9      1
# 1                  2                1          584                20      0
# 2                  1                0          757                21      0
# 3                  1                2          232                18      0
# 4                  2                0          533                18      0

# %%
from sklearn.linear_model import LogisticRegression as LR

# %%
x = df.iloc[:,:-1]

# %%
y = df.iloc[:,-1]

# %%
x_train, x_test, y_train, y_test = tts(x, y, test_size = 0.25, random_state = 42)

# %%
lr = LR()

# %%
lr.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8013545420653659

# %%
conMat = cm(y_test, y_pred)

# Plot the confusion matrix using seaborn heatmap
sns.heatmap(conMat, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted: 0', 'Predicted: 1'], yticklabels=['Actual: 0', 'Actual: 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
